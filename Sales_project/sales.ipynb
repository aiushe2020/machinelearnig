# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\user\\Downloads\\all_file.csv')

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
#
#                           filename
# 0  Sales_Data/Sales_April_2019.csv
# 1  Sales_Data/Sales_April_2019.csv
# 2  Sales_Data/Sales_April_2019.csv
# 3  Sales_Data/Sales_April_2019.csv
# 4  Sales_Data/Sales_April_2019.csv

# %%
data = data.drop(columns='filename')

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
data.shape
# Out:
# (186850, 6)

# %%
data.isnull()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1           True     True              True        True        True
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# ...

# %%
data.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
data1 = data.dropna()

# %%
data1.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
data1.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
data1.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data1['month'] = data1['Order Date'].str[:2]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8244/2690659617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['month'] = data1['Order Date'].str[:2]

# %%
data1.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
data1['month'].dtypes
# Out:
# dtype('O')

# %%
data1['Order ID'].unique()
# Out:
# array(['176558', '176559', '176560', ..., '259355', '259356', '259357'],
#       dtype=object)

# %%
data1['Quantity Ordered'].unique()
# Out:
# array(['2', '1', '3', '5', 'Quantity Ordered', '4', '7', '6', '8', '9'],
#       dtype=object)

# %%
data1['Price Each'].unique()
# Out:
# array(['11.95', '99.99', '600', '11.99', '1700', '14.95', '389.99',
#        '3.84', '150', '2.99', '700', '300', '149.99', '109.99', '600.0',
#        '999.99', '400', '379.99', 'Price Each', '700.0', '1700.0',
#        '150.0', '300.0', '400.0'], dtype=object)

# %%
X = data1.set_index('Order ID')

# %%
X.head()
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
# 176561              Wired Headphones                1      11.99
#
#               Order Date                      Purchase Address month
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
X.drop('Order ID', inplace= True )

# %%
X['Quantity Ordered'].unique()
# Out:
# array(['2', '1', '3', '5', '4', '7', '6', '8', '9'], dtype=object)

# %%
X['Price Each'].unique()
# Out:
# array(['11.95', '99.99', '600', '11.99', '1700', '14.95', '389.99',
#        '3.84', '150', '2.99', '700', '300', '149.99', '109.99', '600.0',
#        '999.99', '400', '379.99', '700.0', '1700.0', '150.0', '300.0',
#        '400.0'], dtype=object)

# %%
X['Quantity Ordered'] = X['Quantity Ordered'].astype(float)

# %%
X['Quantity Ordered'].dtype
# Out:
# dtype('float64')

# %%
X['Price Each'] = X['Price Each'].astype(float)

# %%
X['Price Each'].dtype
# Out:
# dtype('float64')

# %%
X['Sales'] = X['Price Each'] * X['Quantity Ordered'].astype(float)

# %%
X.head()
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 176558          USB-C Charging Cable               2.0       11.95
# 176559    Bose SoundSport Headphones               1.0       99.99
# 176560                  Google Phone               1.0      600.00
# 176560              Wired Headphones               1.0       11.99
# 176561              Wired Headphones               1.0       11.99
#
#               Order Date                      Purchase Address month   Sales
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99

# %%
X['month'].unique()
# Out:
# array(['04', '05', '08', '09', '12', '01', '02', '03', '07', '06', '11',
#        '10'], dtype=object)

# %%
Sales = X.groupby('month').sum()

# %%
Sales.head(12)
# Out:
#        Quantity Ordered  Price Each       Sales
# month
# 01              10903.0  1811768.38  1822256.73
# 02              13449.0  2188884.72  2202022.42
# 03              17005.0  2791207.83  2807100.38
# 04              20558.0  3367671.02  3390670.24
# 05              18667.0  3135125.13  3152606.75
# 06              15253.0  2562025.61  2577802.26
# 07              16072.0  2632539.56  2647775.76
# 08              13448.0  2230345.42  2244467.88
# 09              13109.0  2084992.09  2097560.13
# 10              22703.0  3715554.83  3736726.88
# 11              19798.0  3180600.68  3199603.20
# 12              28114.0  4588415.41  4613443.34

# %%
Sales.sort_values(by = 'Sales', ascending= False )
# Out:
#        Quantity Ordered  Price Each       Sales
# month
# 12              28114.0  4588415.41  4613443.34
# 10              22703.0  3715554.83  3736726.88
# 04              20558.0  3367671.02  3390670.24
# 11              19798.0  3180600.68  3199603.20
# 05              18667.0  3135125.13  3152606.75
# 03              17005.0  2791207.83  2807100.38
# 07              16072.0  2632539.56  2647775.76
# 06              15253.0  2562025.61  2577802.26
# 08              13448.0  2230345.42  2244467.88
# 02              13449.0  2188884.72  2202022.42
# 09              13109.0  2084992.09  2097560.13
# 01              10903.0  1811768.38  1822256.73

# %%
Sales.head()
# Out:
#        Quantity Ordered  Price Each       Sales
# month
# 01              10903.0  1811768.38  1822256.73
# 02              13449.0  2188884.72  2202022.42
# 03              17005.0  2791207.83  2807100.38
# 04              20558.0  3367671.02  3390670.24
# 05              18667.0  3135125.13  3152606.75

# %%
Sales[['Sales']]
# Out:
#             Sales
# month
# 01     1822256.73
# 02     2202022.42
# 03     2807100.38
# 04     3390670.24
# 05     3152606.75
# 06     2577802.26
# 07     2647775.76
# 08     2244467.88
# 09     2097560.13
# 10     3736726.88
# 11     3199603.20
# 12     4613443.34

# %%
# plotting sales vs month
# which city has more sales
# which time is high for salesx

# %%
X.head()
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 176558          USB-C Charging Cable               2.0       11.95
# 176559    Bose SoundSport Headphones               1.0       99.99
# 176560                  Google Phone               1.0      600.00
# 176560              Wired Headphones               1.0       11.99
# 176561              Wired Headphones               1.0       11.99
#
#               Order Date                      Purchase Address month   Sales
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99

# %%
months = range(1,13)

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(months, Sales['Sales'], color='pink', width=0.5)
plt.xlabel('MONTH')
plt.ylabel('Sales')
plt.title('Sales VS months')
plt.ylim(0,5000000)
plt.show()

# %%
X[['Purchase Address']]
# Out:
#                                  Purchase Address
# Order ID
# 176558               917 1st St, Dallas, TX 75001
# 176559          682 Chestnut St, Boston, MA 02215
# 176560       669 Spruce St, Los Angeles, CA 90001
# 176560       669 Spruce St, Los Angeles, CA 90001
# 176561          333 8th St, Los Angeles, CA 90001
# ...                                           ...
# 259353     840 Highland St, Los Angeles, CA 90001
# 259354    216 Dogwood St, San Francisco, CA 94016
# 259355       220 12th St, San Francisco, CA 94016
# 259356     511 Forest St, San Francisco, CA 94016
# 259357     250 Meadow St, San Francisco, CA 94016
#
# [185950 rows x 1 columns]

# %%
X['Cities'] = X['Purchase Address'].apply(lambda x: x.split(",")[1])

# %%
X['Cities']
# Out:
# Order ID
# 176558            Dallas
# 176559            Boston
# 176560       Los Angeles
# 176560       Los Angeles
# 176561       Los Angeles
#                ...
# 259353       Los Angeles
# 259354     San Francisco
# 259355     San Francisco
# 259356     San Francisco
# 259357     San Francisco
# Name: Cities, Length: 185950, dtype: object

# %%
sale_by_city = X.groupby('Cities').sum()

# %%
X['Cities']
# Out:
# Order ID
# 176558            Dallas
# 176559            Boston
# 176560       Los Angeles
# 176560       Los Angeles
# 176561       Los Angeles
#                ...
# 259353       Los Angeles
# 259354     San Francisco
# 259355     San Francisco
# 259356     San Francisco
# 259357     San Francisco
# Name: Cities, Length: 185950, dtype: object

# %%
X.head()
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 176558          USB-C Charging Cable               2.0       11.95
# 176559    Bose SoundSport Headphones               1.0       99.99
# 176560                  Google Phone               1.0      600.00
# 176560              Wired Headphones               1.0       11.99
# 176561              Wired Headphones               1.0       11.99
#
#               Order Date                      Purchase Address month   Sales  \
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#                 Cities
# Order ID
# 176558          Dallas
# ...

# %%
sale_by_city
# Out:
#                 Quantity Ordered  Price Each       Sales
# Cities
#  Atlanta                 16602.0  2779908.20  2795498.58
#  Austin                  11153.0  1809873.61  1819581.75
#  Boston                  22528.0  3637409.77  3661642.01
#  Dallas                  16730.0  2752627.82  2767975.40
#  Los Angeles             33289.0  5421435.23  5452570.80
#  New York City           27932.0  4635370.83  4664317.43
#  Portland                14053.0  2307747.47  2320490.61
#  San Francisco           50239.0  8211461.74  8262203.91
#  Seattle                 16553.0  2733296.01  2747755.48

# %%
sale_by_city.sort_values(by = 'Sales', ascending= False)
# Out:
#                 Quantity Ordered  Price Each       Sales
# Cities
#  San Francisco           50239.0  8211461.74  8262203.91
#  Los Angeles             33289.0  5421435.23  5452570.80
#  New York City           27932.0  4635370.83  4664317.43
#  Boston                  22528.0  3637409.77  3661642.01
#  Atlanta                 16602.0  2779908.20  2795498.58
#  Dallas                  16730.0  2752627.82  2767975.40
#  Seattle                 16553.0  2733296.01  2747755.48
#  Portland                14053.0  2307747.47  2320490.61
#  Austin                  11153.0  1809873.61  1819581.75

# %%
fig = plt.figure(figsize=(15,10))
city = [x for x, X in X.groupby('Cities')]
plt.bar(city, sale_by_city['Sales'], color = 'hotpink')

plt.show()
